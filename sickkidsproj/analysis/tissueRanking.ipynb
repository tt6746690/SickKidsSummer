# %%
import numpy as np
import json
import os
import scipy.stats

# WD="/hpf/projects/brudno/wangpeiq/sickkids_summer/"

WD = "../"
RESOURCES = WD + "resources/"
STORE = WD + "resources/exon_expr/"
PANELDIR = WD + "resources/gene_panels/"

EXONEXPR_MAPPING = WD + "resources/exon_expr.mapping"
ONE_EXONEXPR = STORE + "47/ENSG00000182533"

GENE_PANEL_DIR = WD + "resources/gene_panels/"
GENE_PANEL  = [
    "channelopathies",
    "congenital_myasthenic_syndromes",
    "distal_myopathies",
    "limb_girdle_dystrophies",
    "congenital_muscular_dystrophies",
    "congenital_myopathy",
    "muscular_dystrophies",
    "vacuolar_and_others"
]

GENE_PANEL_PATH = [GENE_PANEL_DIR + gp for gp in GENE_PANEL]

TISSUE_SITE_LIST = STORE + "tissue_site_list"

THRESHOLD = 20
SIGNIFICANCE_LEVEL = 0.05

# %%
# Bidirectional hash table 
ref = {}
ref_rev = {}

with open(TISSUE_SITE_LIST, "r") as f:
    idx = 0
    for ts in f.read().split('\n'):
        ref[ts] = idx 
        ref_rev[idx] = ts
        idx += 1
        
def ts_to_id(ts):
    return ref[ts]
def id_to_ts(id):
    return ref_rev[id]

# %%
def computeSumStat(l):
    lsorted = sorted(l)
    sumStat = {}
    
    sumStat["reads"] = lsorted
    sumStat["median"] = np.percentile(lsorted, 50) 
    sumStat["mean"] = np.mean(lsorted) 
    sumStat["ttest_1samp"] = scipy.stats.ttest_1samp(lsorted, THRESHOLD)
    
    sumStat["overByMedian"] = True if (sumStat["median"] > THRESHOLD) else False
    sumStat["overByMean"] = True if (sumStat["mean"] > THRESHOLD) else False
    sumStat["overByTtest"] = True if (sumStat["ttest_1samp"][0] > 0 and 
                                      sumStat["ttest_1samp"][1]/2 <= SIGNIFICANCE_LEVEL) else False
    return sumStat



def prelimRanking(input):
#     data = input["exonExpression"]
#     exonexpr = input["exonExpression"]
    exonexpr = input
    
    for exonNum in exonexpr:
        exon = exonexpr[exonNum]
        for tissueSite in exon:
            d = exon[tissueSite] 
            
            # Determine the basis for computing tissue Ranking
            # If exon reads for this exonNum and tissueSite 
            # -- is over threshold, 
            # ---- then d["otherTissue"] holds tissue names that is also over threshold
            # -- is not over threshold
            # ---- then d["otherTissue"] is empty
            # 
            d["otherTissue"] = []
            if d["overByTtest"]:
                for ts in exon:
                    other = exon[ts]
                    if other["overByTtest"]:
                        d["otherTissue"].append(ts_to_id(ts))
            d["otherTissue"].sort()
    
    '''
    tissueRanking: {
        ..., referenceTissueSite:{
            total: [ ..., exonNum ],
            sub: { ...,
                rankedTissueSite: [ ..., exonNum ]
            },
            ranking: [ ..., [rankedTissueSite, sub, fraction] ]
        }
    }
    indexed by id converted by ts_to_id, 
    and sorted by sub/total ratio in descending order
    -- total: exon in referenceTissueSite over threshold
    -- sub: by tissueSite, exonNum that is also over threshold 
    ---- given that exonNum in referenceTissueSite is over threshold
    -- ranking: a list of rankedTissueSite sorted in descending order 
    ---- w.r.t. len(rankedTissuSite) / len(total)
    
    '''
    # init dictionary 
    tissueRanking = {}
    for k in ref:
        tissueRanking[k] = {}
        tissueRanking[k]["total"] = []
        tissueRanking[k]["sub"] = {}
        
    # populate total and sub
    for exonNum in exonexpr:
        exon = exonexpr[exonNum]
        for tissueSite in exon:
            d = exon[tissueSite]
             
            refTissueSite = tissueRanking[tissueSite]
            if d["overByMedian"]:
                refTissueSite["total"].append(exonNum)
            
            for otherts in d["otherTissue"]:
                if id_to_ts(otherts) not in refTissueSite["sub"]:
                    refTissueSite["sub"][id_to_ts(otherts)] = []
                refTissueSite["sub"][id_to_ts(otherts)].append(exonNum) 

                
    # Generate ranking 
    for refk in ref:
        
        ranking = []
        refTissueSite = tissueRanking[refk]
        
        total = len(refTissueSite["total"])
        for rankk in refTissueSite["sub"]:
            rankedTissueSite = refTissueSite["sub"][rankk]
            t = [rankk, len(rankedTissueSite), len(rankedTissueSite)/total if total != 0 else 0]
            ranking.append(t)
        
        ranking.sort(key=lambda x: x[1], reverse=True)
        tissueRanking[refk]["ranking"] = ranking

    data = {}
    data["tissueRanking"] = tissueRanking
    data["exonExpression"] = exonexpr
    
    return data
      
        
def computeStatOne(gp):
    
    print("generating summary stat {}...".format(gp))
     
    exonexpr = {}
    with open(gp, "r") as f:
        exonexpr = json.loads(f.read())
        
        if "exonExpression" not in exonexpr:
            # compute summary statistis
            data = {}
            for exonNum in exonexpr["exon_expression"]:

                data[exonNum] = {}
                exon = exonexpr["exon_expression"][exonNum]
                for tissueSite in exon:
                    reads = exon[tissueSite]    
                    sumStat = computeSumStat(reads)

                    data[exonNum][tissueSite] = sumStat

            with open(gp + ".p", "w") as f:
                json.dump(data, f)
        else:
            with open(gp + ".p", "w") as f:
                json.dump(exonexpr, f)
            print("skipping generating summary stat {}...".format(gp))


def computeRankingOne(gp):
    print("generating ranking for {}".format(gp))
    
    with open(gp + ".p", "r") as f:
        exonexpr = json.loads(f.read())
        
        if "exonExpression" not in exonexpr:
            withRanking = prelimRanking(exonexpr)
            with open(gp + ".p", "w") as f:
                json.dump(withRanking, f)
        else:
            print("skipping generating ranking for {}".format(gp))

             
    
# computeStatOne(ONE_EXONEXPR)
# computeRankingOne(ONE_EXONEXPR)

# %%
firsttime=True
for root, dirs, files in os.walk(STORE, topdown=True):
    if firsttime:
        firsttime=False
        continue
    
    for f in files:
        gp = os.path.join(root, f)
        if os.path.splitext(gp)[1] is "":
            print(gp + "...")
            computeStatOne(gp)
            computeRankingOne(gp)
# Out:
# ../resources/exon_expr/1/ENSG00000102119...
# generating summary stat ../resources/exon_expr/1/ENSG00000102119...
# generating ranking for ../resources/exon_expr/1/ENSG00000102119
# ../resources/exon_expr/100/ENSG00000111262...
# generating summary stat ../resources/exon_expr/100/ENSG00000111262...
# generating ranking for ../resources/exon_expr/100/ENSG00000111262
# ../resources/exon_expr/101/ENSG00000133424...
# generating summary stat ../resources/exon_expr/101/ENSG00000133424...
# skipping generating summary stat ../resources/exon_expr/101/ENSG00000133424...
# generating ranking for ../resources/exon_expr/101/ENSG00000133424
# skipping generating ranking for ../resources/exon_expr/101/ENSG00000133424
# ../resources/exon_expr/101/ENSG00000196811...
# generating summary stat ../resources/exon_expr/101/ENSG00000196811...
# skipping generating summary stat ../resources/exon_expr/101/ENSG00000196811...
# generating ranking for ../resources/exon_expr/101/ENSG00000196811
# skipping generating ranking for ../resources/exon_expr/101/ENSG00000196811
# ../resources/exon_expr/103/ENSG00000196296...
# generating summary stat ../resources/exon_expr/103/ENSG00000196296...
# generating ranking for ../resources/exon_expr/103/ENSG00000196296
# ../resources/exon_expr/104/ENSG00000168538...
# generating summary stat ../resources/exon_expr/104/ENSG00000168538...
# skipping generating summary stat ../resources/exon_expr/104/ENSG00000168538...
# generating ranking for ../resources/exon_expr/104/ENSG00000168538
# skipping generating ranking for ../resources/exon_expr/104/ENSG00000168538
# ../resources/exon_expr/105/ENSG00000108556...
# generating summary stat ../resources/exon_expr/105/ENSG00000108556...
# skipping generating summary stat ../resources/exon_expr/105/ENSG00000108556...
# generating ranking for ../resources/exon_expr/105/ENSG00000108556
# skipping generating ranking for ../resources/exon_expr/105/ENSG00000108556
# ../resources/exon_expr/106/ENSG00000196569...
# generating summary stat ../resources/exon_expr/106/ENSG00000196569...
# skipping generating summary stat ../resources/exon_expr/106/ENSG00000196569...
# generating ranking for ../resources/exon_expr/106/ENSG00000196569
# skipping generating ranking for ../resources/exon_expr/106/ENSG00000196569
# ../resources/exon_expr/108/ENSG00000175538...
# generating summary stat ../resources/exon_expr/108/ENSG00000175538...
# generating ranking for ../resources/exon_expr/108/ENSG00000175538
# ../resources/exon_expr/109/ENSG00000188037...
# generating summary stat ../resources/exon_expr/109/ENSG00000188037...
# generating ranking for ../resources/exon_expr/109/ENSG00000188037
# ../resources/exon_expr/11/ENSG00000234438...
# generating summary stat ../resources/exon_expr/11/ENSG00000234438...
# skipping generating summary stat ../resources/exon_expr/11/ENSG00000234438...
# generating ranking for ../resources/exon_expr/11/ENSG00000234438
# skipping generating ranking for ../resources/exon_expr/11/ENSG00000234438
# ../resources/exon_expr/113/ENSG00000157119...
# generating summary stat ../resources/exon_expr/113/ENSG00000157119...
# skipping generating summary stat ../resources/exon_expr/113/ENSG00000157119...
# generating ranking for ../resources/exon_expr/113/ENSG00000157119
# skipping generating ranking for ../resources/exon_expr/113/ENSG00000157119
# ../resources/exon_expr/114/ENSG00000135424...
# generating summary stat ../resources/exon_expr/114/ENSG00000135424...
# skipping generating summary stat ../resources/exon_expr/114/ENSG00000135424...
# generating ranking for ../resources/exon_expr/114/ENSG00000135424
# skipping generating ranking for ../resources/exon_expr/114/ENSG00000135424
# ../resources/exon_expr/115/ENSG00000142173...
# generating summary stat ../resources/exon_expr/115/ENSG00000142173...
# skipping generating summary stat ../resources/exon_expr/115/ENSG00000142173...
# generating ranking for ../resources/exon_expr/115/ENSG00000142173
# skipping generating ranking for ../resources/exon_expr/115/ENSG00000142173
# ../resources/exon_expr/115/ENSG00000198467...
# generating summary stat ../resources/exon_expr/115/ENSG00000198467...
# skipping generating summary stat ../resources/exon_expr/115/ENSG00000198467...
# generating ranking for ../resources/exon_expr/115/ENSG00000198467
# skipping generating ranking for ../resources/exon_expr/115/ENSG00000198467
# ../resources/exon_expr/116/ENSG00000100288...
# generating summary stat ../resources/exon_expr/116/ENSG00000100288...
# skipping generating summary stat ../resources/exon_expr/116/ENSG00000100288...
# generating ranking for ../resources/exon_expr/116/ENSG00000100288
# skipping generating ranking for ../resources/exon_expr/116/ENSG00000100288
# ../resources/exon_expr/117/ENSG00000172269...
# generating summary stat ../resources/exon_expr/117/ENSG00000172269...
# generating ranking for ../resources/exon_expr/117/ENSG00000172269
# ../resources/exon_expr/119/ENSG00000170876...
# generating summary stat ../resources/exon_expr/119/ENSG00000170876...
# generating ranking for ../resources/exon_expr/119/ENSG00000170876
# ../resources/exon_expr/12/ENSG00000145794...
# generating summary stat ../resources/exon_expr/12/ENSG00000145794...
# skipping generating summary stat ../resources/exon_expr/12/ENSG00000145794...
# generating ranking for ../resources/exon_expr/12/ENSG00000145794
# skipping generating ranking for ../resources/exon_expr/12/ENSG00000145794
# ../resources/exon_expr/120/ENSG00000129749...
# generating summary stat ../resources/exon_expr/120/ENSG00000129749...
# skipping generating summary stat ../resources/exon_expr/120/ENSG00000129749...
# generating ranking for ../resources/exon_expr/120/ENSG00000129749
# skipping generating ranking for ../resources/exon_expr/120/ENSG00000129749
# ../resources/exon_expr/121/ENSG00000079805...
# generating summary stat ../resources/exon_expr/121/ENSG00000079805...
# skipping generating summary stat ../resources/exon_expr/121/ENSG00000079805...
# generating ranking for ../resources/exon_expr/121/ENSG00000079805
# skipping generating ranking for ../resources/exon_expr/121/ENSG00000079805
# ../resources/exon_expr/121/ENSG00000121350...
# generating summary stat ../resources/exon_expr/121/ENSG00000121350...
# generating ranking for ../resources/exon_expr/121/ENSG00000121350
# ../resources/exon_expr/123/ENSG00000135902...
# generating summary stat ../resources/exon_expr/123/ENSG00000135902...
# skipping generating summary stat ../resources/exon_expr/123/ENSG00000135902...
# generating ranking for ../resources/exon_expr/123/ENSG00000135902
# skipping generating ranking for ../resources/exon_expr/123/ENSG00000135902
# ../resources/exon_expr/125/ENSG00000092054...
# generating summary stat ../resources/exon_expr/125/ENSG00000092054...
# skipping generating summary stat ../resources/exon_expr/125/ENSG00000092054...
# generating ranking for ../resources/exon_expr/125/ENSG00000092054
# skipping generating ranking for ../resources/exon_expr/125/ENSG00000092054
# ../resources/exon_expr/125/ENSG00000135636...
# generating summary stat ../resources/exon_expr/125/ENSG00000135636...
# generating ranking for ../resources/exon_expr/125/ENSG00000135636
# ../resources/exon_expr/133/ENSG00000138379...
# generating summary stat ../resources/exon_expr/133/ENSG00000138379...
# generating ranking for ../resources/exon_expr/133/ENSG00000138379
# ../resources/exon_expr/134/ENSG00000105048...
# generating summary stat ../resources/exon_expr/134/ENSG00000105048...
# skipping generating summary stat ../resources/exon_expr/134/ENSG00000105048...
# generating ranking for ../resources/exon_expr/134/ENSG00000105048
# skipping generating ranking for ../resources/exon_expr/134/ENSG00000105048
# ../resources/exon_expr/134/ENSG00000179085...
# generating summary stat ../resources/exon_expr/134/ENSG00000179085...
# generating ranking for ../resources/exon_expr/134/ENSG00000179085
# ../resources/exon_expr/135/ENSG00000122367...
# generating summary stat ../resources/exon_expr/135/ENSG00000122367...
# generating ranking for ../resources/exon_expr/135/ENSG00000122367
# ../resources/exon_expr/136/ENSG00000131018...
# generating summary stat ../resources/exon_expr/136/ENSG00000131018...
# generating ranking for ../resources/exon_expr/136/ENSG00000131018
# ../resources/exon_expr/138/ENSG00000092529...
# generating summary stat ../resources/exon_expr/138/ENSG00000092529...
# generating ranking for ../resources/exon_expr/138/ENSG00000092529
# ../resources/exon_expr/139/ENSG00000022267...
# generating summary stat ../resources/exon_expr/139/ENSG00000022267...
# skipping generating summary stat ../resources/exon_expr/139/ENSG00000022267...
# generating ranking for ../resources/exon_expr/139/ENSG00000022267
# skipping generating ranking for ../resources/exon_expr/139/ENSG00000022267
# ../resources/exon_expr/139/ENSG00000162885...
# generating summary stat ../resources/exon_expr/139/ENSG00000162885...
# skipping generating summary stat ../resources/exon_expr/139/ENSG00000162885...
# generating ranking for ../resources/exon_expr/139/ENSG00000162885
# skipping generating ranking for ../resources/exon_expr/139/ENSG00000162885
# ../resources/exon_expr/139/ENSG00000185900...
# generating summary stat ../resources/exon_expr/139/ENSG00000185900...
# skipping generating summary stat ../resources/exon_expr/139/ENSG00000185900...
# generating ranking for ../resources/exon_expr/139/ENSG00000185900
# skipping generating ranking for ../resources/exon_expr/139/ENSG00000185900
# ../resources/exon_expr/14/ENSG00000138347...
# generating summary stat ../resources/exon_expr/14/ENSG00000138347...
# generating ranking for ../resources/exon_expr/14/ENSG00000138347
# ../resources/exon_expr/141/ENSG00000102683...
# generating summary stat ../resources/exon_expr/141/ENSG00000102683...
# generating ranking for ../resources/exon_expr/141/ENSG00000102683
# ../resources/exon_expr/141/ENSG00000141837...
# generating summary stat ../resources/exon_expr/141/ENSG00000141837...
# generating ranking for ../resources/exon_expr/141/ENSG00000141837
# ../resources/exon_expr/145/ENSG00000009830...
# generating summary stat ../resources/exon_expr/145/ENSG00000009830...
# skipping generating summary stat ../resources/exon_expr/145/ENSG00000009830...
# generating ranking for ../resources/exon_expr/145/ENSG00000009830
# skipping generating ranking for ../resources/exon_expr/145/ENSG00000009830
# ../resources/exon_expr/145/ENSG00000116001...
# generating summary stat ../resources/exon_expr/145/ENSG00000116001...
# generating ranking for ../resources/exon_expr/145/ENSG00000116001
# ../resources/exon_expr/147/ENSG00000206561...
# generating summary stat ../resources/exon_expr/147/ENSG00000206561...
# skipping generating summary stat ../resources/exon_expr/147/ENSG00000206561...
# generating ranking for ../resources/exon_expr/147/ENSG00000206561
# skipping generating ranking for ../resources/exon_expr/147/ENSG00000206561
# ../resources/exon_expr/151/ENSG00000018236...
# generating summary stat ../resources/exon_expr/151/ENSG00000018236...
# skipping generating summary stat ../resources/exon_expr/151/ENSG00000018236...
# generating ranking for ../resources/exon_expr/151/ENSG00000018236
# skipping generating ranking for ../resources/exon_expr/151/ENSG00000018236
# ../resources/exon_expr/151/ENSG00000165917...
# generating summary stat ../resources/exon_expr/151/ENSG00000165917...
# skipping generating summary stat ../resources/exon_expr/151/ENSG00000165917...
# generating ranking for ../resources/exon_expr/151/ENSG00000165917
# skipping generating ranking for ../resources/exon_expr/151/ENSG00000165917
# ../resources/exon_expr/153/ENSG00000072163...
# generating summary stat ../resources/exon_expr/153/ENSG00000072163...
# generating ranking for ../resources/exon_expr/153/ENSG00000072163
# ../resources/exon_expr/153/ENSG00000142798...
# generating summary stat ../resources/exon_expr/153/ENSG00000142798...
# generating ranking for ../resources/exon_expr/153/ENSG00000142798
# ../resources/exon_expr/153/ENSG00000165410...
# generating summary stat ../resources/exon_expr/153/ENSG00000165410...
# skipping generating summary stat ../resources/exon_expr/153/ENSG00000165410...
# generating ranking for ../resources/exon_expr/153/ENSG00000165410
# skipping generating ranking for ../resources/exon_expr/153/ENSG00000165410
# ../resources/exon_expr/154/ENSG00000133454...
# generating summary stat ../resources/exon_expr/154/ENSG00000133454...
# skipping generating summary stat ../resources/exon_expr/154/ENSG00000133454...
# generating ranking for ../resources/exon_expr/154/ENSG00000133454
# skipping generating ranking for ../resources/exon_expr/154/ENSG00000133454
# ../resources/exon_expr/154/ENSG00000198642...
# generating summary stat ../resources/exon_expr/154/ENSG00000198642...
# generating ranking for ../resources/exon_expr/154/ENSG00000198642
# ../resources/exon_expr/156/ENSG00000138100...
# generating summary stat ../resources/exon_expr/156/ENSG00000138100...
# generating ranking for ../resources/exon_expr/156/ENSG00000138100
# ../resources/exon_expr/157/ENSG00000125414...
# generating summary stat ../resources/exon_expr/157/ENSG00000125414...
# skipping generating summary stat ../resources/exon_expr/157/ENSG00000125414...
# generating ranking for ../resources/exon_expr/157/ENSG00000125414
# skipping generating ranking for ../resources/exon_expr/157/ENSG00000125414
# ../resources/exon_expr/158/ENSG00000138435...
# generating summary stat ../resources/exon_expr/158/ENSG00000138435...
# skipping generating summary stat ../resources/exon_expr/158/ENSG00000138435...
# generating ranking for ../resources/exon_expr/158/ENSG00000138435
# skipping generating ranking for ../resources/exon_expr/158/ENSG00000138435
# ../resources/exon_expr/159/ENSG00000162004...
# generating summary stat ../resources/exon_expr/159/ENSG00000162004...
# skipping generating summary stat ../resources/exon_expr/159/ENSG00000162004...
# generating ranking for ../resources/exon_expr/159/ENSG00000162004
# skipping generating ranking for ../resources/exon_expr/159/ENSG00000162004
# ../resources/exon_expr/165/ENSG00000170175...
# generating summary stat ../resources/exon_expr/165/ENSG00000170175...
# skipping generating summary stat ../resources/exon_expr/165/ENSG00000170175...
# generating ranking for ../resources/exon_expr/165/ENSG00000170175
# skipping generating ranking for ../resources/exon_expr/165/ENSG00000170175
# ../resources/exon_expr/166/ENSG00000118600...
# generating summary stat ../resources/exon_expr/166/ENSG00000118600...
# skipping generating summary stat ../resources/exon_expr/166/ENSG00000118600...
# generating ranking for ../resources/exon_expr/166/ENSG00000118600
# skipping generating ranking for ../resources/exon_expr/166/ENSG00000118600
# ../resources/exon_expr/167/ENSG00000173402...
# generating summary stat ../resources/exon_expr/167/ENSG00000173402...
# generating ranking for ../resources/exon_expr/167/ENSG00000173402
# ../resources/exon_expr/17/ENSG00000160131...
# generating summary stat ../resources/exon_expr/17/ENSG00000160131...
# generating ranking for ../resources/exon_expr/17/ENSG00000160131
# ../resources/exon_expr/17/ENSG00000170624...
# generating summary stat ../resources/exon_expr/17/ENSG00000170624...
# generating ranking for ../resources/exon_expr/17/ENSG00000170624
# ../resources/exon_expr/173/ENSG00000184185...
# generating summary stat ../resources/exon_expr/173/ENSG00000184185...
# generating ranking for ../resources/exon_expr/173/ENSG00000184185
# ../resources/exon_expr/178/ENSG00000144647...
# generating summary stat ../resources/exon_expr/178/ENSG00000144647...
# generating ranking for ../resources/exon_expr/178/ENSG00000144647
# ../resources/exon_expr/18/ENSG00000072195...
# generating summary stat ../resources/exon_expr/18/ENSG00000072195...
# skipping generating summary stat ../resources/exon_expr/18/ENSG00000072195...
# generating ranking for ../resources/exon_expr/18/ENSG00000072195
# skipping generating ranking for ../resources/exon_expr/18/ENSG00000072195
# ../resources/exon_expr/18/ENSG00000160789...
# generating summary stat ../resources/exon_expr/18/ENSG00000160789...
# skipping generating summary stat ../resources/exon_expr/18/ENSG00000160789...
# generating ranking for ../resources/exon_expr/18/ENSG00000160789
# skipping generating ranking for ../resources/exon_expr/18/ENSG00000160789
# ../resources/exon_expr/180/ENSG00000070748...
# generating summary stat ../resources/exon_expr/180/ENSG00000070748...
# skipping generating summary stat ../resources/exon_expr/180/ENSG00000070748...
# generating ranking for ../resources/exon_expr/180/ENSG00000070748
# skipping generating ranking for ../resources/exon_expr/180/ENSG00000070748
# ../resources/exon_expr/184/ENSG00000175084...
# generating summary stat ../resources/exon_expr/184/ENSG00000175084...
# generating ranking for ../resources/exon_expr/184/ENSG00000175084
# ../resources/exon_expr/190/ENSG00000030304...
# generating summary stat ../resources/exon_expr/190/ENSG00000030304...
# skipping generating summary stat ../resources/exon_expr/190/ENSG00000030304...
# generating ranking for ../resources/exon_expr/190/ENSG00000030304
# skipping generating ranking for ../resources/exon_expr/190/ENSG00000030304
# ../resources/exon_expr/191/ENSG00000085998...
# generating summary stat ../resources/exon_expr/191/ENSG00000085998...
# skipping generating summary stat ../resources/exon_expr/191/ENSG00000085998...
# generating ranking for ../resources/exon_expr/191/ENSG00000085998
# skipping generating ranking for ../resources/exon_expr/191/ENSG00000085998
# ../resources/exon_expr/191/ENSG00000173991...
# generating summary stat ../resources/exon_expr/191/ENSG00000173991...
# skipping generating summary stat ../resources/exon_expr/191/ENSG00000173991...
# generating ranking for ../resources/exon_expr/191/ENSG00000173991
# skipping generating ranking for ../resources/exon_expr/191/ENSG00000173991
# ../resources/exon_expr/191/ENSG00000188603...
# generating summary stat ../resources/exon_expr/191/ENSG00000188603...
# generating ranking for ../resources/exon_expr/191/ENSG00000188603
# ../resources/exon_expr/192/ENSG00000115170...
# generating summary stat ../resources/exon_expr/192/ENSG00000115170...
# generating ranking for ../resources/exon_expr/192/ENSG00000115170
# ../resources/exon_expr/195/ENSG00000130714...
# generating summary stat ../resources/exon_expr/195/ENSG00000130714...
# skipping generating summary stat ../resources/exon_expr/195/ENSG00000130714...
# generating ranking for ../resources/exon_expr/195/ENSG00000130714
# skipping generating ranking for ../resources/exon_expr/195/ENSG00000130714
# ../resources/exon_expr/199/ENSG00000081248...
# generating summary stat ../resources/exon_expr/199/ENSG00000081248...
# generating ranking for ../resources/exon_expr/199/ENSG00000081248
# ../resources/exon_expr/199/ENSG00000171714...
# generating summary stat ../resources/exon_expr/199/ENSG00000171714...
# generating ranking for ../resources/exon_expr/199/ENSG00000171714
# ../resources/exon_expr/22/ENSG00000171298...
# generating summary stat ../resources/exon_expr/22/ENSG00000171298...
# generating ranking for ../resources/exon_expr/22/ENSG00000171298
# ../resources/exon_expr/23/ENSG00000065526...
# generating summary stat ../resources/exon_expr/23/ENSG00000065526...
# skipping generating summary stat ../resources/exon_expr/23/ENSG00000065526...
# generating ranking for ../resources/exon_expr/23/ENSG00000065526
# skipping generating ranking for ../resources/exon_expr/23/ENSG00000065526
# ../resources/exon_expr/23/ENSG00000120729...
# generating summary stat ../resources/exon_expr/23/ENSG00000120729...
# generating ranking for ../resources/exon_expr/23/ENSG00000120729
# ../resources/exon_expr/23/ENSG00000163359...
# generating summary stat ../resources/exon_expr/23/ENSG00000163359...
# skipping generating summary stat ../resources/exon_expr/23/ENSG00000163359...
# generating ranking for ../resources/exon_expr/23/ENSG00000163359
# skipping generating ranking for ../resources/exon_expr/23/ENSG00000163359
# ../resources/exon_expr/23/ENSG00000165280...
# generating summary stat ../resources/exon_expr/23/ENSG00000165280...
# generating ranking for ../resources/exon_expr/23/ENSG00000165280
# ../resources/exon_expr/24/ENSG00000136717...
# generating summary stat ../resources/exon_expr/24/ENSG00000136717...
# skipping generating summary stat ../resources/exon_expr/24/ENSG00000136717...
# generating ranking for ../resources/exon_expr/24/ENSG00000136717
# skipping generating ranking for ../resources/exon_expr/24/ENSG00000136717
# ../resources/exon_expr/26/ENSG00000172339...
# generating summary stat ../resources/exon_expr/26/ENSG00000172339...
# skipping generating summary stat ../resources/exon_expr/26/ENSG00000172339...
# generating ranking for ../resources/exon_expr/26/ENSG00000172339
# skipping generating ranking for ../resources/exon_expr/26/ENSG00000172339
# ../resources/exon_expr/26/ENSG00000196218...
# generating summary stat ../resources/exon_expr/26/ENSG00000196218...
# skipping generating summary stat ../resources/exon_expr/26/ENSG00000196218...
# generating ranking for ../resources/exon_expr/26/ENSG00000196218
# skipping generating ranking for ../resources/exon_expr/26/ENSG00000196218
# ../resources/exon_expr/27/ENSG00000000419...
# generating summary stat ../resources/exon_expr/27/ENSG00000000419...
# skipping generating summary stat ../resources/exon_expr/27/ENSG00000000419...
# generating ranking for ../resources/exon_expr/27/ENSG00000000419
# skipping generating ranking for ../resources/exon_expr/27/ENSG00000000419
# ../resources/exon_expr/28/ENSG00000143858...
# generating summary stat ../resources/exon_expr/28/ENSG00000143858...
# skipping generating summary stat ../resources/exon_expr/28/ENSG00000143858...
# generating ranking for ../resources/exon_expr/28/ENSG00000143858
# skipping generating ranking for ../resources/exon_expr/28/ENSG00000143858
# ../resources/exon_expr/28/ENSG00000183091...
# generating summary stat ../resources/exon_expr/28/ENSG00000183091...
# skipping generating summary stat ../resources/exon_expr/28/ENSG00000183091...
# generating ranking for ../resources/exon_expr/28/ENSG00000183091
# skipping generating ranking for ../resources/exon_expr/28/ENSG00000183091
# ../resources/exon_expr/29/ENSG00000136003...
# generating summary stat ../resources/exon_expr/29/ENSG00000136003...
# generating ranking for ../resources/exon_expr/29/ENSG00000136003
# ../resources/exon_expr/3/ENSG00000054654...
# generating summary stat ../resources/exon_expr/3/ENSG00000054654...
# generating ranking for ../resources/exon_expr/3/ENSG00000054654
# ../resources/exon_expr/3/ENSG00000171100...
# generating summary stat ../resources/exon_expr/3/ENSG00000171100...
# skipping generating summary stat ../resources/exon_expr/3/ENSG00000171100...
# generating ranking for ../resources/exon_expr/3/ENSG00000171100
# skipping generating ranking for ../resources/exon_expr/3/ENSG00000171100
# ../resources/exon_expr/34/ENSG00000188157...
# generating summary stat ../resources/exon_expr/34/ENSG00000188157...
# skipping generating summary stat ../resources/exon_expr/34/ENSG00000188157...
# generating ranking for ../resources/exon_expr/34/ENSG00000188157
# skipping generating ranking for ../resources/exon_expr/34/ENSG00000188157
# ../resources/exon_expr/38/ENSG00000128591...
# generating summary stat ../resources/exon_expr/38/ENSG00000128591...
# generating ranking for ../resources/exon_expr/38/ENSG00000128591
# ../resources/exon_expr/39/ENSG00000158022...
# generating summary stat ../resources/exon_expr/39/ENSG00000158022...
# generating ranking for ../resources/exon_expr/39/ENSG00000158022
# ../resources/exon_expr/40/ENSG00000015479...
# generating summary stat ../resources/exon_expr/40/ENSG00000015479...
# generating ranking for ../resources/exon_expr/40/ENSG00000015479
# ../resources/exon_expr/43/ENSG00000159921...
# generating summary stat ../resources/exon_expr/43/ENSG00000159921...
# generating ranking for ../resources/exon_expr/43/ENSG00000159921
# ../resources/exon_expr/45/ENSG00000108823...
# generating summary stat ../resources/exon_expr/45/ENSG00000108823...
# generating ranking for ../resources/exon_expr/45/ENSG00000108823
# ../resources/exon_expr/45/ENSG00000163719...
# generating summary stat ../resources/exon_expr/45/ENSG00000163719...
# skipping generating summary stat ../resources/exon_expr/45/ENSG00000163719...
# generating ranking for ../resources/exon_expr/45/ENSG00000163719
# skipping generating ranking for ../resources/exon_expr/45/ENSG00000163719
# ../resources/exon_expr/47/ENSG00000182533...
# generating summary stat ../resources/exon_expr/47/ENSG00000182533...
# generating ranking for ../resources/exon_expr/47/ENSG00000182533
# ../resources/exon_expr/49/ENSG00000143337...
# generating summary stat ../resources/exon_expr/49/ENSG00000143337...
# generating ranking for ../resources/exon_expr/49/ENSG00000143337
# ../resources/exon_expr/50/ENSG00000119523...
# generating summary stat ../resources/exon_expr/50/ENSG00000119523...
# skipping generating summary stat ../resources/exon_expr/50/ENSG00000119523...
# generating ranking for ../resources/exon_expr/50/ENSG00000119523
# skipping generating ranking for ../resources/exon_expr/50/ENSG00000119523
# ../resources/exon_expr/53/ENSG00000007314...
# generating summary stat ../resources/exon_expr/53/ENSG00000007314...
# skipping generating summary stat ../resources/exon_expr/53/ENSG00000007314...
# generating ranking for ../resources/exon_expr/53/ENSG00000007314
# skipping generating ranking for ../resources/exon_expr/53/ENSG00000007314
# ../resources/exon_expr/53/ENSG00000138078...
# generating summary stat ../resources/exon_expr/53/ENSG00000138078...
# skipping generating summary stat ../resources/exon_expr/53/ENSG00000138078...
# generating ranking for ../resources/exon_expr/53/ENSG00000138078
# skipping generating ranking for ../resources/exon_expr/53/ENSG00000138078
# ../resources/exon_expr/54/ENSG00000119401...
# generating summary stat ../resources/exon_expr/54/ENSG00000119401...
# generating ranking for ../resources/exon_expr/54/ENSG00000119401
# ../resources/exon_expr/58/ENSG00000152795...
# generating summary stat ../resources/exon_expr/58/ENSG00000152795...
# generating ranking for ../resources/exon_expr/58/ENSG00000152795
# ../resources/exon_expr/62/ENSG00000101901...
# generating summary stat ../resources/exon_expr/62/ENSG00000101901...
# skipping generating summary stat ../resources/exon_expr/62/ENSG00000101901...
# generating ranking for ../resources/exon_expr/62/ENSG00000101901
# skipping generating ranking for ../resources/exon_expr/62/ENSG00000101901
# ../resources/exon_expr/63/ENSG00000198380...
# generating summary stat ../resources/exon_expr/63/ENSG00000198380...
# skipping generating summary stat ../resources/exon_expr/63/ENSG00000198380...
# generating ranking for ../resources/exon_expr/63/ENSG00000198380
# skipping generating ranking for ../resources/exon_expr/63/ENSG00000198380
# ../resources/exon_expr/65/ENSG00000106692...
# generating summary stat ../resources/exon_expr/65/ENSG00000106692...
# skipping generating summary stat ../resources/exon_expr/65/ENSG00000106692...
# generating ranking for ../resources/exon_expr/65/ENSG00000106692
# skipping generating ranking for ../resources/exon_expr/65/ENSG00000106692
# ../resources/exon_expr/65/ENSG00000163069...
# generating summary stat ../resources/exon_expr/65/ENSG00000163069...
# generating ranking for ../resources/exon_expr/65/ENSG00000163069
# ../resources/exon_expr/66/ENSG00000142156...
# generating summary stat ../resources/exon_expr/66/ENSG00000142156...
# skipping generating summary stat ../resources/exon_expr/66/ENSG00000142156...
# generating ranking for ../resources/exon_expr/66/ENSG00000142156
# skipping generating ranking for ../resources/exon_expr/66/ENSG00000142156
# ../resources/exon_expr/66/ENSG00000198947...
# generating summary stat ../resources/exon_expr/66/ENSG00000198947...
# generating ranking for ../resources/exon_expr/66/ENSG00000198947
# ../resources/exon_expr/68/ENSG00000172037...
# generating summary stat ../resources/exon_expr/68/ENSG00000172037...
# skipping generating summary stat ../resources/exon_expr/68/ENSG00000172037...
# generating ranking for ../resources/exon_expr/68/ENSG00000172037
# skipping generating ranking for ../resources/exon_expr/68/ENSG00000172037
# ../resources/exon_expr/7/ENSG00000109846...
# generating summary stat ../resources/exon_expr/7/ENSG00000109846...
# generating ranking for ../resources/exon_expr/7/ENSG00000109846
# ../resources/exon_expr/70/ENSG00000178209...
# generating summary stat ../resources/exon_expr/70/ENSG00000178209...
# skipping generating summary stat ../resources/exon_expr/70/ENSG00000178209...
# generating ranking for ../resources/exon_expr/70/ENSG00000178209
# skipping generating ranking for ../resources/exon_expr/70/ENSG00000178209
# ../resources/exon_expr/72/ENSG00000239474...
# generating summary stat ../resources/exon_expr/72/ENSG00000239474...
# skipping generating summary stat ../resources/exon_expr/72/ENSG00000239474...
# generating ranking for ../resources/exon_expr/72/ENSG00000239474
# skipping generating ranking for ../resources/exon_expr/72/ENSG00000239474
# ../resources/exon_expr/75/ENSG00000136908...
# generating summary stat ../resources/exon_expr/75/ENSG00000136908...
# skipping generating summary stat ../resources/exon_expr/75/ENSG00000136908...
# generating ranking for ../resources/exon_expr/75/ENSG00000136908
# skipping generating ranking for ../resources/exon_expr/75/ENSG00000136908
# ../resources/exon_expr/76/ENSG00000105993...
# generating summary stat ../resources/exon_expr/76/ENSG00000105993...
# generating ranking for ../resources/exon_expr/76/ENSG00000105993
# ../resources/exon_expr/76/ENSG00000143549...
# generating summary stat ../resources/exon_expr/76/ENSG00000143549...
# skipping generating summary stat ../resources/exon_expr/76/ENSG00000143549...
# generating ranking for ../resources/exon_expr/76/ENSG00000143549
# skipping generating ranking for ../resources/exon_expr/76/ENSG00000143549
# ../resources/exon_expr/79/ENSG00000121964...
# generating summary stat ../resources/exon_expr/79/ENSG00000121964...
# skipping generating summary stat ../resources/exon_expr/79/ENSG00000121964...
# generating ranking for ../resources/exon_expr/79/ENSG00000121964
# skipping generating ranking for ../resources/exon_expr/79/ENSG00000121964
# ../resources/exon_expr/79/ENSG00000185482...
# generating summary stat ../resources/exon_expr/79/ENSG00000185482...
# skipping generating summary stat ../resources/exon_expr/79/ENSG00000185482...
# generating ranking for ../resources/exon_expr/79/ENSG00000185482
# skipping generating ranking for ../resources/exon_expr/79/ENSG00000185482
# ../resources/exon_expr/82/ENSG00000175920...
# generating summary stat ../resources/exon_expr/82/ENSG00000175920...
# skipping generating summary stat ../resources/exon_expr/82/ENSG00000175920...
# generating ranking for ../resources/exon_expr/82/ENSG00000175920
# skipping generating ranking for ../resources/exon_expr/82/ENSG00000175920
# ../resources/exon_expr/82/ENSG00000196730...
# generating summary stat ../resources/exon_expr/82/ENSG00000196730...
# skipping generating summary stat ../resources/exon_expr/82/ENSG00000196730...
# generating ranking for ../resources/exon_expr/82/ENSG00000196730
# skipping generating ranking for ../resources/exon_expr/82/ENSG00000196730
# ../resources/exon_expr/82/ENSG00000214960...
# generating summary stat ../resources/exon_expr/82/ENSG00000214960...
# skipping generating summary stat ../resources/exon_expr/82/ENSG00000214960...
# generating ranking for ../resources/exon_expr/82/ENSG00000214960
# skipping generating ranking for ../resources/exon_expr/82/ENSG00000214960
# ../resources/exon_expr/85/ENSG00000163380...
# generating summary stat ../resources/exon_expr/85/ENSG00000163380...
# skipping generating summary stat ../resources/exon_expr/85/ENSG00000163380...
# generating ranking for ../resources/exon_expr/85/ENSG00000163380
# skipping generating ranking for ../resources/exon_expr/85/ENSG00000163380
# ../resources/exon_expr/86/ENSG00000101596...
# generating summary stat ../resources/exon_expr/86/ENSG00000101596...
# generating ranking for ../resources/exon_expr/86/ENSG00000101596
# ../resources/exon_expr/88/ENSG00000167323...
# generating summary stat ../resources/exon_expr/88/ENSG00000167323...
# generating ranking for ../resources/exon_expr/88/ENSG00000167323
# ../resources/exon_expr/9/ENSG00000064419...
# generating summary stat ../resources/exon_expr/9/ENSG00000064419...
# generating ranking for ../resources/exon_expr/9/ENSG00000064419
# ../resources/exon_expr/91/ENSG00000181027...
# generating summary stat ../resources/exon_expr/91/ENSG00000181027...
# skipping generating summary stat ../resources/exon_expr/91/ENSG00000181027...
# generating ranking for ../resources/exon_expr/91/ENSG00000181027
# skipping generating ranking for ../resources/exon_expr/91/ENSG00000181027
# ../resources/exon_expr/94/ENSG00000151929...
# generating summary stat ../resources/exon_expr/94/ENSG00000151929...
# generating ranking for ../resources/exon_expr/94/ENSG00000151929
# ../resources/exon_expr/95/ENSG00000143632...
# generating summary stat ../resources/exon_expr/95/ENSG00000143632...
# skipping generating summary stat ../resources/exon_expr/95/ENSG00000143632...
# generating ranking for ../resources/exon_expr/95/ENSG00000143632
# skipping generating ranking for ../resources/exon_expr/95/ENSG00000143632
# ../resources/exon_expr/99/ENSG00000155657...
# generating summary stat ../resources/exon_expr/99/ENSG00000155657...
# skipping generating summary stat ../resources/exon_expr/99/ENSG00000155657...
# generating ranking for ../resources/exon_expr/99/ENSG00000155657
# skipping generating ranking for ../resources/exon_expr/99/ENSG00000155657

# %%
# get mapping 
mapping = {}
with open(EXONEXPR_MAPPING, "r") as f:
    for g in f.read().split('\n'):
        pair = g.split('\t')
        if len(pair) == 2:
            mapping[pair[0]] = pair[1]


def computeRankingForPanel(gp):
    '''
    panelRanking: {
            ..., referenceTissueSite:{
                total: int,
                ranking: {
                    ..., rankedTIssueSite: {
                        sub,           ## total 
                        fraction: []   ## for each
                    }
                }                      ## later converted to [rankingTissueSite, sub, medianFraction]
            }
        }

    '''


    panelRanking = {}

    for k in ref:
        panelRanking[k] = {}
        panelRanking[k]["total"] = 0
        panelRanking[k]["ranking"] = {}
        for kk in ref:
            panelRanking[k]["ranking"][kk] = {}
            panelRanking[k]["ranking"][kk]["sub"] = 0
            panelRanking[k]["ranking"][kk]["fraction"] = []


    for path in gp:
        with open(path, "r") as f:
            g = json.loads(f.read())
            rankingForGene = g["tissueRanking"]
            for refTissueSite in rankingForGene:

                refTissueRanking = rankingForGene[refTissueSite]

                panelRanking[refTissueSite]["total"] += len(refTissueRanking["total"])
                for truple in refTissueRanking["ranking"]:
                    rankedTissueSite = truple[0]
                    numOfExon = truple[1]
                    frac = truple[2]
                    panelRanking[refTissueSite]["ranking"][rankedTissueSite]["sub"] += numOfExon
                    panelRanking[refTissueSite]["ranking"][rankedTissueSite]["fraction"].append(frac)

    # convert dict to list and sort the ranking list
    for refTissue in panelRanking: 
        rankingList = []
        refRanking = panelRanking[refTissue]["ranking"]
        for rankedTissue in refRanking:
            refRanking[rankedTissue]["fraction"].sort(reverse=True)

            sub = refRanking[rankedTissue]["sub"]
            medianFraction = np.percentile(refRanking[rankedTissue]["fraction"], 50) \
                if refRanking[rankedTissue]["fraction"] else 0
            rankingList.append([rankedTissue, sub, medianFraction])

        del panelRanking[refTissue]["ranking"]
        rankingList.sort(key=lambda x: x[2], reverse=True)      # sort by medianFraction
        panelRanking[refTissue]["ranking"] = rankingList
        
    return panelRanking
    # write result

def ComputeRankingForAllPanel():
    
    for gpp in GENE_PANEL_PATH:
        
        # Get a list of path for genes in panel
        gp = []
        with open(gpp, "r") as f:
            for g in f.read().split('\n'):
                if len(g.split('\t')) == 2:
                    ensemblId = g.split('\t')[1]
                    if ensemblId in mapping:
                        gp.append(RESOURCES + mapping[ensemblId] + ".p")
        
        print("compute ranking for {}...".format(gpp))
        ranking = computeRankingForPanel(gp)
        
        with open(gpp + ".ranking", "w+") as outf:
            json.dump(ranking, outf)
   
ComputeRankingForAllPanel()
# Out:
# compute ranking for ../resources/gene_panels/channelopathies...
# compute ranking for ../resources/gene_panels/congenital_myasthenic_syndromes...
# compute ranking for ../resources/gene_panels/distal_myopathies...
# compute ranking for ../resources/gene_panels/limb_girdle_dystrophies...
# compute ranking for ../resources/gene_panels/congenital_muscular_dystrophies...
# compute ranking for ../resources/gene_panels/congenital_myopathy...
# compute ranking for ../resources/gene_panels/muscular_dystrophies...
# compute ranking for ../resources/gene_panels/vacuolar_and_others...
